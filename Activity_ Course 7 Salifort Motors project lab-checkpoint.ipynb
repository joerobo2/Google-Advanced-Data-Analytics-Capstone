# %% [markdown]
# # **Capstone project: Providing data-driven suggestions for HR**

# %% [markdown]
# ## Description and deliverables
#
# This capstone project is an opportunity for you to analyze a dataset and build predictive models that can provide insights to the Human Resources (HR) department of a large consulting firm.
#
# Upon completion, you will have two artifacts that you would be able to present to future employers. One is a brief one-page summary of this project that you would present to external stakeholders as the data professional in Salifort Motors. The other is a complete code notebook provided here. Please consider your prior course work and select one way to achieve this given project question. Either use a regression model or machine learning model to predict whether or not an employee will leave the company. The exemplar following this actiivty shows both approaches, but you only need to do one.
#
# In your deliverables, you will include the model evaluation (and interpretation if applicable), a data visualization(s) of your choice that is directly related to the question you ask, ethical considerations, and the resources you used to troubleshoot and find answers or solutions.

# %% [markdown]
# # **PACE stages**

# %% [markdown]
# ![Screenshot 2022-08-04 5.47.37 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## **Pace: Plan**
#
# Consider the questions in your PACE Strategy Document to reflect on the Plan stage.
#
# In this stage, consider the following:

# %% [markdown]
# ### Understand the business scenario and problem
#
# The HR department at Salifort Motors wants to take some initiatives to improve employee satisfaction levels at the company. They collected data from employees, but now they don’t know what to do with it. They refer to you as a data analytics professional and ask you to provide data-driven suggestions based on your understanding of the data. They have the following question: what’s likely to make the employee leave the company?
#
# Your goals in this project are to analyze the data collected by the HR department and to build a model that predicts whether or not an employee will leave the company.
#
# If you can predict employees likely to quit, it might be possible to identify factors that contribute to their leaving. Because it is time-consuming and expensive to find, interview, and hire new employees, increasing employee retention will be beneficial to the company.

# %% [markdown]
# ### Familiarize yourself with the HR dataset
#
# The dataset that you'll be using in this lab contains 15,000 rows and 10 columns for the variables listed below.
#
# **Note:** you don't need to download any data to complete this lab. For more information about the data, refer to its source on [Kaggle](https://www.kaggle.com/datasets/mfaisalqureshi/hr-analytics-and-job-prediction?select=HR_comma_sep.csv).
#
# Variable  |Description |
# -----|-----|
# satisfaction_level|Employee-reported job satisfaction level [0&ndash;1]|
# last_evaluation|Score of employee's last performance review [0&ndash;1]|
# number_project|Number of projects employee contributes to|
# average_monthly_hours|Average number of hours employee worked per month|
# time_spend_company|How long the employee has been with the company (years)
# Work_accident|Whether or not the employee experienced an accident while at work
# left|Whether or not the employee left the company
# promotion_last_5years|Whether or not the employee was promoted in the last 5 years
# Department|The employee's department
# salary|The employee's salary (U.S. dollars)

# %% [markdown]
# 💭
# ### Reflect on these questions as you complete the plan stage.
#
# *  Who are your stakeholders for this project?
# - What are you trying to solve or accomplish?
# - What are your initial observations when you explore the data?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# [Double-click to enter your responses here.]
#
# Who are your stakeholders for this project?
#
# Salifort Motors HR team and C-Suite
#
# What are you trying to solve or accomplish?
#
# We are tasked to create a model to predict employee retention/turnover.
#
# What are your initial observations when you explore the data?
#
# I have all of the data I need to make this model, though it could be more effective if I had a couple of continuous variables, like Salary instead of bins, as it could provide further context.
#
# What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
#
# pandas, numpy, seaborn, and matplotlib for EDA.
#
# Do you have any ethical considerations in this stage?
#
# Ensuring that my model is not unduly judging employees based on age, sex, gender, or race. Presently, none of my variables are doing that.

# %% [markdown]
# ## Step 1. Imports
#
# *   Import packages
# *   Load dataset

# %% [markdown]
# ### Import packages

# %%
# Import packages
### YOUR CODE HERE ### 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
#from sklearn.feature_selection import permutation_importance

# %% [markdown]
# ### Load dataset
#
# `Pandas` is used to read a dataset called **`HR_capstone_dataset.csv`.**  As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA. 

# Load dataset into a dataframe
### YOUR CODE HERE ###
df = pd.read_csv("HR_capstone_dataset.csv")


# Display first few rows of the dataframe
### YOUR CODE HERE ###
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# ## Step 2. Data Exploration (Initial EDA and data cleaning)
#
# - Understand your variables
# - Clean your dataset (missing data, redundant data, outliers)

# %% [markdown]
# ### Gather basic information about the data

# %%
# Gather basic information about the data
### YOUR CODE HERE ###
print(df.shape)
print(df.info())
# Out:
# (14999, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# ### Gather descriptive statistics about the data

# %%
# Gather descriptive statistics about the data
### YOUR CODE HERE ###
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# ### Rename columns

# %% [markdown]
# As a data cleaning step, rename the columns as needed. Standardize the column names so that they are all in `snake_case`, correct any column names that are misspelled, and make column names more concise as needed.

# %%
# Display all column names
### YOUR CODE HERE ###
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
# Rename columns as needed
### YOUR CODE HERE ###
df = df.rename(columns={'average_montly_hours': 'avg_mo_hrs', 'time_spend_company':'tenure', 'Work_accident': 'work_accident', 'promotion_last_5years': 'promotion', 'Department': 'department'})

# Display all column names after the update
### YOUR CODE HERE ###
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project', 'avg_mo_hrs',
#        'tenure', 'work_accident', 'left', 'promotion', 'department', 'salary'],
#       dtype='object')

# %% [markdown]
# ### Check missing values

# %% [markdown]
# Check for any missing values in the data.

# %%
# Check for missing values
### YOUR CODE HERE ###
df.isna().sum()
# Out:
# satisfaction_level    0
# last_evaluation       0
# number_project        0
# avg_mo_hrs            0
# tenure                0
# work_accident         0
# left                  0
# promotion             0
# department            0
# salary                0
# dtype: int64

# %% [markdown]
# ### Check duplicates

# %% [markdown]
# Check for any duplicate entries in the data.

# %%
# Check for duplicates
### YOUR CODE HERE ###
mask = df.duplicated()
duplicates = df[mask]

# %%
# Inspect some rows containing duplicates as needed
### YOUR CODE HERE ###
duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3008 entries, 396 to 14998
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   satisfaction_level  3008 non-null   float64
#  1   last_evaluation     3008 non-null   float64
#  2   number_project      3008 non-null   int64
#  3   avg_mo_hrs          3008 non-null   int64
#  4   tenure              3008 non-null   int64
#  5   work_accident       3008 non-null   int64
#  6   left                3008 non-null   int64
#  7   promotion           3008 non-null   int64
#  8   department          3008 non-null   object
#  9   salary              3008 non-null   object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 258.5+ KB

# %%
# Drop duplicates and save resulting dataframe in a new variable as needed
### YOUR CODE HERE ###

df1 = df.drop_duplicates()
# Display first few rows of new dataframe as needed
### YOUR CODE HERE ###
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11991 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   satisfaction_level  11991 non-null  float64
#  1   last_evaluation     11991 non-null  float64
#  2   number_project      11991 non-null  int64
#  3   avg_mo_hrs          11991 non-null  int64
#  4   tenure              11991 non-null  int64
#  5   work_accident       11991 non-null  int64
#  6   left                11991 non-null  int64
#  7   promotion           11991 non-null  int64
#  8   department          11991 non-null  object
#  9   salary              11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Check outliers

# %% [markdown]
# Check for outliers in the data.

# %%
# Create a boxplot to visualize distribution of `tenure` and detect any outliers
### YOUR CODE HERE ###

plt.figure(figsize=(15,4))
sns.boxplot(x=df1.tenure)
plt.title('Distribution of Tenure', fontsize=19)
plt.xlabel('Years of Tenure', fontsize=14)
# Out:
# Text(0.5, 0, 'Years of Tenure')

# %%
# Determine the number of rows containing outliers
### YOUR CODE HERE ###

mask1 = df1['tenure'] > 5
df1[mask1].shape
mask2 = df1['tenure'] <= 5
df1= df1[mask2]
df1.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project    avg_mo_hrs  \
# count        11167.000000     11167.000000    11167.000000  11167.000000
# mean             0.631944         0.715901        3.786066    200.144533
# std              0.239064         0.167595        1.164198     48.563047
# min              0.090000         0.360000        2.000000     96.000000
# 25%              0.490000         0.570000        3.000000    157.000000
# 50%              0.660000         0.720000        4.000000    199.000000
# 75%              0.820000         0.860000        5.000000    243.000000
# max              1.000000         1.000000        7.000000    310.000000
#
#              tenure  work_accident          left     promotion
# count  11167.000000   11167.000000  11167.000000  11167.000000
# mean       3.109161       0.152413      0.168532      0.014417
# std        0.899277       0.359437      0.374355      0.119209
# ...

# %% [markdown]
# Certain types of models are more sensitive to outliers than others. When you get to the stage of building your model, consider whether to remove outliers, based on the type of model you decide to use.

# %% [markdown]
# # pAce: Analyze Stage
# - Perform EDA (analyze relationships between variables)

# %% [markdown]
# 💭
# ### Reflect on these questions as you complete the analyze stage.
#
# - What did you observe about the relationships between variables?
# - What do you observe about the distributions in the data?
# - What transformations did you make with your data? Why did you chose to make those decisions?
# - What are some purposes of EDA before constructing a predictive model?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# [Double-click to enter your responses here.]
#
# What did you observe about the relationships between variables?
#
# These variables meet the assumption oh non-multicolinear.
#
# What do you observe about the distributions in the data?
#
# Many are right skewed, and binomial, however, they are approx. normal distributed for the most part.
#
# What transformations did you make with your data? Why did you chose to make those decisions?
#
# What are some purposes of EDA before constructing a predictive model?
#
# What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
#
# Google Gemini has been very helpful for import statements and workflow ideas.
#
# Do you have any ethical considerations in this stage?
#
# I am removing Work Accident as a variable as I found it has weak predictive power in the overall model.

# %% [markdown]
# ## Step 2. Data Exploration (Continue EDA)
#
# Begin by understanding how many employees left and what percentage of all employees this figure represents.

# %%
# Get numbers of people who left vs. stayed
### YOUR CODE HERE ###
print(df1['left'].value_counts())
# Get percentages of people who left vs. stayed
### YOUR CODE HERE ###
print(df1['left'].value_counts(normalize=True) *100)
# Out:
# 0    9285
# 1    1882
# Name: left, dtype: int64
# 0    83.146772
# 1    16.853228
# Name: left, dtype: float64

# %% [markdown]
# ### Data visualizations

# %% [markdown]
# Now, examine variables that you're interested in, and create plots to visualize relationships between variables in the data.

# %%
# Create a plot as needed
### YOUR CODE HERE ###
sns.pairplot(df1)

# %%
# Create a plot as needed
### YOUR CODE HERE ###
df1.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project', 'avg_mo_hrs',
#        'tenure', 'work_accident', 'left', 'promotion', 'department', 'salary'],
#       dtype='object')

# %%
# Create a plot as needed
### YOUR CODE HERE ###


plt.figure(figsize=(20,8))
sns.boxplot(x=df1.left, y= df1.number_project)

# %%
# Create a plot as needed
### YOUR CODE HERE ###
sns.histplot(df1.number_project)

# %%
# Create a plot as needed
### YOUR CODE HERE ###
sns.histplot(df1.avg_mo_hrs)

# %%
# Create a plot as needed
### YOUR CODE HERE ###
sns.histplot(df1.salary)

# %%
# Create a plot as needed
### YOUR CODE HERE ###
mask4 = df1['left'] ==1
df2 = df1[mask4]
#df2.groupby(['department', 'left'])['salary'].value_counts(normalize = True).sort_values(ascending=False)*100
#df2.groupby(['department', 'left'])['satisfaction_level'].value_counts(normalize = True).sort_values(ascending=False)*100
df2.last_evaluation.sort_values(ascending=False)
# Out:
# 943     1.00
# 422     1.00
# 807     1.00
# 689     1.00
# 156     1.00
#         ...
# 1493    0.45
# 129     0.45
# 1184    0.45
# 715     0.45
# 1367    0.45
# Name: last_evaluation, Length: 1882, dtype: float64

# %%
# Create a plot as needed
### YOUR CODE HERE ###

# %% [markdown]
# ### Insights

# %% [markdown]
# [What insights can you gather from the plots you created to visualize the data? Double-click to enter your responses here.]
#
# Logistic Regression Assumptions:
# Binary Dependent Variable
#     Left is broken into 0 and 1
# Non-co-linear assumption is met
# Independence assumption is assumed met
#     Based on the pairplot there doesn't seem to be any linear correlation
# Outliers have been removed
#
# Department + Left + Salary:
# This is a strong predictive variable.
#
# Between 68% and 51% of employee attrition per Department based on low Salary are in the following departments in descending order:
# Marketing, Support, Technical, Management, RandD, Sales, HR, Accounting, IT, Product Management
#
# Between 44% and 28% of employee attrition per Department based on medium Salary are in the following departments in descending order:
# IT, Product Management, HR, Sales, Accounting, Management, RandD, Technical, Support, Marketing
#
# Between 5.5% and 1.3% of employee attrition per Department based on high Salary are in the following departments in descending order:
# RandD, Product Management, Marketing, Accounting, HR, Technical, Management, IT, Support, Sales
#
# Department + Left + Work Accident:
# This is a weak predictive variable.
#
# Between 97% and 90% of employees per Department that have left the company have not had a work-related accident.
#
# Only 9.2% and 2.56% of employees per Department that have left the company have also had or reported a work-related accident.
#
# Department + Left + Number of Projects:
# This is a strong predictive variable.
#
# Between 69% and 50% of employee attrition per Department were only assigned 2 work projects.
#     Conjecture1: Employees left because they felt under-used
#     Conjecture2: Employees were poor performers
#     Conjecture3: Employees did not want more proojects
# Between 28% and 16% of employee attrition per Department had exactly 6 projects.
#     Conjecture1: Employee left because they were overworked
#     Conjecture2: Employee left because the work load was mismanaged
# Between 16% to 0.8% of employee attrition per Department had 3, 4, 5, or 7 projects.
#
# Department + Left + Promotion:
# This is a strong predictive variable.
#
# Between 100% to 97% of employee attrition per Department were not promoted.
#
# Between 2.3% and 0.36% of employee attrition per Department were promoted.
# The only 4 offices to promote in the last 5 years were: IT, Sales Support, and Technical
#
# Department + Left + Last Evaluation:
# Decent predictive variable, but ethically?
#
# Between 12.8% and 9.2% of employee attrition per Department received poor evaluations between 0.46 to 0.54 (out of 1.00)
# However, the highest evaluation score of an employee who was not retained is 1.00
#
# Department + Left + Satisfaction Level:
# Decent predictive variable.
#
# Between 15% and 18% of employee attrition had extremely low Satisfaction Levels of .10 and .11 respectively.
# However, the highest Satisfacton level that still churned is 0.90.

# %% [markdown]
# # paCe: Construct Stage
# - Determine which models are most appropriate
# - Construct the model
# - Confirm model assumptions
# - Evaluate model results to determine how well your model fits the data

# %% [markdown]
# 🔎
# ## Recall model assumptions
#
# **Logistic Regression model assumptions**
# - Outcome variable is categorical
# - Observations are independent of each other
# - No severe multicollinearity among X variables
# - No extreme outliers
# - Linear relationship between each X variable and the logit of the outcome variable
# - Sufficiently large sample size

# %% [markdown]
# 💭
# ### Reflect on these questions as you complete the constructing stage.
#
# - Do you notice anything odd?
# - Which independent variables did you choose for the model and why?
# - Are each of the assumptions met?
# - How well does your model fit the data?
# - Can you improve it? Is there anything you would change about the model?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# [Double-click to enter your responses here.]
#
# Do you notice anything odd?
#
# I am surprise Work Accident isn't a stronger predictive variable based on my EDA.
#
# Which independent variables did you choose for the model and why?
#
# satisfaction_level, salary, last_evaluation, promotion, number_projects
#
# Are each of the assumptions met?
#
# I believe so.
#
# How well does your model fit the data?
#
#
# Firstly, I created both a Logistic Regression and a Random Forest model for this data set. The Random Forest Classifier is the champion model that will be presented to stakeholders for deployment. The following explains the models and their nuances:
#
# Logistic Regression:
# Performance reflects how well the model separates classes based on a single, learned relationship between features and the target variable.
#
# Random Forest Classifier:
# Performance reflects the collective performance of an ensemble (group) of decision trees, potentially capturing more complex relationships in the data.
#
#
# The following are key differences in evaluation and interpretation:
#
#
# Accuracy:
# Both: Similar interpretation-- Proportion of correctly classified data points (True Positive or True Negative).
# Difference: Logistic Regression may be more suceptible to class imbalance leading to misleading accuracy. The target variable 'left' has an 83/16 split, which is not ideal and could cause issues for this type of model.
#
# Precision:
# Both: Measures the proportion of True Positives (TP) among predicted positives or (how many positives were predicted correctly?)
# Difference: Random Forest bagging technique may provide some resilience to class imbalance issues over Logistic Regression.
#
# Recall:
# Both: Measures the proportion of TPs identified by the model or (how well does the model find actual TPs?)
# Difference: Again, Random Forest is more robust in terms of resistence to class imbalance than Logistic Regression.
#
# F1 Score:
# Both: Harmonic mean of precision and recall, providing a balanced view of model performance.
# Difference: Interpretation remains the same, but, again, Random Forest is more resilient to class imbalances.
#
#
#
# The Logistic Regression Model when run on the test data fits as follows:
#    model	precision	recall	          F1	accuracy
# Final LR	0.474576	0.237960	0.316981	0.827125
#
# The precision score measures the proportion of True Positive (TP) among all predicted positives. A score of 0.47 means that there is a 47% chance that these TP will be calculated correctly. (Predicted) This score could mean that the model did not take well to the 83/16 split, and the data set may need to either be upsampled or downsampled to run more efficiently.
#
# The recall score measures the proportion of TPs identified by the model and reflects how well the model finds all the actual positive cases. A score of 0.23 means that there is a 23% chance that a TP will be calculated correctly against all actual positive cases. (Actual) This score could mean that the model did not take well to the 83/16 split, and the data set may need to either be upsampled or downsampled to run more efficiently.
#
# An F1 score is a calculation that takes into account both the precision score and recall scores, using the 'harmonic' mean versus the actual mean, since the harmonic mean penalizes models that have low precision or recall scores. An F1 score of 0.31 means that the model performs within a 31% harmonic mean efficacy of both the precision and recall scores. This score could mean that the model did not take well to the 83/16 split, and the data set may need to either be upsampled or downsampled to run more efficiently.
#
# The accuracy score measures the proportion of correct predictions made by the model on the testing set. It is calculated as the number of correctly classified data points divided by the total number of data points. An accuracy score of 0.82 means that there is a 82% chance that the model will accurately classify its predictions. Meaning True Positives (TPs) and True Negatives (TNs) will be 82% accurate. However, based on the scores of precision, recall, and F1, I would call this accuracy score into question. This score could mean that the model did not take well to the 83/16 split, and the data set may need to either be upsampled or downsampled to run more efficiently.
#
# The Random Forest Model when run on the test data fits as follows:
#        model	precision	recall	          F1	accuracy
# 	RF_Final	0.990991	0.934183	0.961749	0.987464
#
# The precision score measures the proportion of True Positive (TP) among all predicted positives. A score of 0.99 means that there is a 99% chance that these TP will be calculated correctly. (Predicted)
#
# The recall score measures the proportion of TPs identified by the model and reflects how well the model finds all the actual positive cases. A score of 0.94 means that there is a 94% chance that a TP will be calculated correctly against all actual positive cases. (Actual)
#
# An F1 score is a calculation that takes into account both the precision score and recall scores, using the 'harmonic' mean versus the actual mean, since the harmonic mean penalizes models that have low precision or recall scores. An F1 score of 0.96 means that the model performs within a 96% harmonic mean efficacy of both the precision and recall scores.
#
# The accuracy score measures the proportion of correct predictions made by the model on the testing set. It is calculated as the number of correctly classified data points divided by the total number of data points. An accuracy score of 0.98 means that there is a 98% chance that the model will accurately classify its predictions. Meaning True Positives (TPs) and True Negatives (TNs) will be 98% accurate.
#
# Can you improve it? Is there anything you would change about the model?
#
# The Logisitic Regression can be improved upon by either upsampling or downsampling the data. Additionally, the Random Forest model provided some insights into the data based on the importance features plot conducted at the end. From that graph the following features or variables could be tuned into to make the model more accurate: satisfaction level, tenure, last evaluation, number projects, and avg monthly hours. Moreover other features could be added, such as a continuous variable for sales with hard values to zero in on some hard numbers for salary.
#
# What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# Do you have any ethical considerations in this stage?
#
# I used previous notes from other labs, Google Gemini to help me with workflow and model questions and evaluation tips. I do not have any ethical considerations at this stage since I removed the features that had ethical issues.

# %% [markdown]
# ## Step 3. Model Building, Step 4. Results and Evaluation
# - Fit a model that predicts the outcome variable using two or more independent variables
# - Check model assumptions
# - Evaluate the model

# %% [markdown]
# ### Identify the type of prediction task.

# %% [markdown]
# [Double-click to enter your responses here.]
#
# Logistic Regression
#
# Decision Tree

# %% [markdown]
# ### Identify the types of models most appropriate for this task.

# %% [markdown]
# [Double-click to enter your responses here.]
#
# Classifiers due to the lack of continous variables.

# %% [markdown]
# ### Modeling
#
# Add as many cells as you need to conduct the modeling process.

# %%
### YOUR CODE HERE ###
y = df1['left']
y.value_counts(normalize=True)
# Out:
# 0    0.831468
# 1    0.168532
# Name: left, dtype: float64

# %%
x= pd.get_dummies(df1, drop_first=True)

# %%
#x = x.drop('work_accident', axis=1)

x = x.drop(['left', 'work_accident'], axis=1)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11167 entries, 0 to 11999
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   satisfaction_level      11167 non-null  float64
#  1   last_evaluation         11167 non-null  float64
#  2   number_project          11167 non-null  int64
#  3   avg_mo_hrs              11167 non-null  int64
#  4   tenure                  11167 non-null  int64
#  5   promotion               11167 non-null  int64
#  6   department_RandD        11167 non-null  uint8
#  7   department_accounting   11167 non-null  uint8
#  8   department_hr           11167 non-null  uint8
#  9   department_management   11167 non-null  uint8
#  10  department_marketing    11167 non-null  uint8
#  11  department_product_mng  11167 non-null  uint8
#  12  department_sales        11167 non-null  uint8
#  13  department_support      11167 non-null  uint8
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25, stratify=y, random_state=42)
x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train,test_size=0.25, stratify=y_train, random_state=42)

# %%
lr= LogisticRegression(solver='liblinear', random_state=0)
lr2= lr.fit(x_tr, y_tr)

# %%
ypred = lr2.predict(x_val)

# %%
acc= accuracy_score(y_val, ypred)
prec= precision_score(y_val, ypred)
rec= recall_score(y_val, ypred)
f1= f1_score(y_val, ypred)

print(f''' 
Accuracy Score: {round(acc, 3)}
Precision Score: {round(prec, 3)}
Recall Score: {round(rec, 3)}
F1 Score: {round(f1, 3)}
''')
# Out:
#
# Accuracy Score: 0.827
# Precision Score: 0.475
# Recall Score: 0.238
# F1 Score: 0.317

# %%
results = pd.DataFrame({'model': 'LR', 'precision': [prec], 'recall': [rec], 'F1': [f1], 'accuracy': [acc]})
results
# Out:
#   model  precision   recall        F1  accuracy
# 0    LR   0.474576  0.23796  0.316981  0.827125

# %%
def conf_matrix_plot(model, x_data, y_data):
    '''
    Accepts as argument model object, X data (test or validate), and y data (test or validate). 
    Return a plot of confusion matrix for predictions on y data.
    ''' 
  
    model_pred = model.predict(x_data)
    cm = confusion_matrix(y_data, model_pred, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=model.classes_,
                                 )
  
    disp.plot(values_format='') # `values_format=''` suppresses scientific notation
    plt.show()

# %%
conf_matrix_plot(lr2, x_val, y_val)

# %%
from sklearn.model_selection import GridSearchCV
# 1. Instantiate the random forest classifier
rf = RandomForestClassifier(random_state=0)

# 2. Create a dictionary of hyperparameters to tune 
# Note that this example only contains 1 value for each parameter for simplicity,
# but you should assign a dictionary with ranges of values
cv_params = {'max_depth': [None],
             'max_features': [1.0],
             'max_samples': [0.7],
             'min_samples_leaf': [1],
             'min_samples_split': [2],
             'n_estimators': [300]
             }

# 3. Define a set of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1'}

# 4. Instantiate the GridSearchCV object
rf2 = GridSearchCV(rf, cv_params, scoring=scoring, cv=4, refit='f1')

# %%
# %%time
rf2.fit(x_tr, y_tr)
# Out:
# CPU times: user 12.8 s, sys: 17.6 ms, total: 12.8 s
# Wall time: 12.9 s
# GridSearchCV(cv=4, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
# ...

# %%
rf2.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 1.0,
#  'max_samples': 0.7,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
rf2.best_score_
# Out:
# 0.9495924976707147

# %%
def make_results(model_name:str, model_object, metric:str):
    '''
    Arguments:
    model_name (string): what you want the model to be called in the output table
    model_object: a fit GridSearchCV object
    metric (string): precision, recall, f1, or accuracy

    Returns a pandas df with the F1, recall, precision, and accuracy scores
    for the model with the best mean 'metric' score across all validation folds.
    '''

    # Create dictionary that maps input metric to actual metric name in GridSearchCV
    metric_dict = {'precision': 'mean_test_precision',
                 'recall': 'mean_test_recall',
                 'f1': 'mean_test_f1',
                 'accuracy': 'mean_test_accuracy',
                 }

    # Get all the results from the CV and put them in a df
    cv_results = pd.DataFrame(model_object.cv_results_)

    # Isolate the row of the df with the max(metric) score
    best_estimator_results = cv_results.iloc[cv_results[metric_dict[metric]].idxmax(), :]

    # Extract Accuracy, precision, recall, and f1 score from that row
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy

    # Create table of results
    table = pd.DataFrame({'model': [model_name],
                        'precision': [precision],
                        'recall': [recall],
                        'F1': [f1],
                        'accuracy': [accuracy],
                        },
                       )

    return table

# %%
rf2_results = make_results('RF_CV', rf2, 'f1')
results = pd.concat([results, rf2_results], axis=0)

# %%
results
# Out:
#    model  precision    recall        F1  accuracy
# 0     LR   0.474576  0.237960  0.316981  0.827125
# 0  RF_CV   0.983842  0.917796  0.949592  0.983601

# %%
rf_preds= rf2.best_estimator_.predict(x_val)

# %%
def get_test_scores(model_name:str, preds, y_test_data):
    '''
    Generate a table of test scores.

    In:
    model_name (string): Your choice: how the model will be named in the output table
    preds: numpy array of test predictions
    y_test_data: numpy array of y_test data

    Out:
    table: a pandas df of precision, recall, f1, and accuracy scores for your model
    '''
    accuracy = accuracy_score(y_test_data, preds)
    precision = precision_score(y_test_data, preds)
    recall = recall_score(y_test_data, preds)
    f1 = f1_score(y_test_data, preds)

    table = pd.DataFrame({'model': [model_name],
                        'precision': [precision],
                        'recall': [recall],
                        'F1': [f1],
                        'accuracy': [accuracy]
                        })

    return table

# %%
RF_Score = get_test_scores('RF_Test', rf_preds, y_val )

# %%
results = pd.concat([results, RF_Score], axis=0)
results
# Out:
#      model  precision    recall        F1  accuracy
# 0       LR   0.474576  0.237960  0.316981  0.827125
# 0    RF_CV   0.983842  0.917796  0.949592  0.983601
# 0  RF_Test   0.987654  0.906516  0.945347  0.982330

# %%
conf_matrix_plot(rf2, x_val, y_val)

# %%
lr2.fit(x_tr, y_tr)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = lr2.predict(x_test)

# %%
acc1= accuracy_score(y_val, ypred)
prec1= precision_score(y_val, ypred)
rec1= recall_score(y_val, ypred)
f11= f1_score(y_val, ypred)

print(f''' 
Accuracy Score: {round(acc1, 3)}
Precision Score: {round(prec1, 3)}
Recall Score: {round(rec1, 3)}
F1 Score: {round(f11, 3)}
''')
# Out:
#
# Accuracy Score: 0.827
# Precision Score: 0.475
# Recall Score: 0.238
# F1 Score: 0.317

# %%
final_lr = pd.DataFrame({'model': 'Final LR', 'precision': [prec1], 'recall': [rec1], 'F1': [f11], 'accuracy': [acc1]})
final_lr
# Out:
#       model  precision   recall        F1  accuracy
# 0  Final LR   0.474576  0.23796  0.316981  0.827125

# %%
rf2.fit(x_tr, y_tr)
# Out:
# GridSearchCV(cv=4, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=0,
# ...

# %%
final_preds= rf2.best_estimator_.predict(x_test)

# %%
final_rf = get_test_scores('RF_Final', final_preds, y_test )

# %%
results = pd.concat([results, final_rf], axis=0)
results
# Out:
#       model  precision    recall        F1  accuracy
# 0        LR   0.474576  0.237960  0.316981  0.827125
# 0     RF_CV   0.983842  0.917796  0.949592  0.983601
# 0   RF_Test   0.987654  0.906516  0.945347  0.982330
# 0  RF_Final   0.990991  0.934183  0.961749  0.987464

# %%
results = pd.concat([results, final_lr], axis=0)
results
# Out:
#       model  precision    recall        F1  accuracy
# 0        LR   0.474576  0.237960  0.316981  0.827125
# 0     RF_CV   0.983842  0.917796  0.949592  0.983601
# 0   RF_Test   0.987654  0.906516  0.945347  0.982330
# 0  RF_Final   0.990991  0.934183  0.961749  0.987464
# 0  Final LR   0.474576  0.237960  0.316981  0.827125

# %%
conf_matrix_plot(lr2, x_test, y_test)

# %%
# %%time
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Sample data (replace with your actual data)


# Calculate false positive rate (fpr) and true positive rate (tpr)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# Calculate Area Under the Curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC Curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='No Skill')  # Reference line for random guessing
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)', fontsize=14)
plt.ylabel('True Positive Rate (TPR)', fontsize=14)
plt.title('Logistic Regression ROC Curve', fontsize=20)
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# CPU times: user 168 ms, sys: 7.93 ms, total: 176 ms
# Wall time: 175 ms

# %%
conf_matrix_plot(rf2, x_test, y_test)

# %%
# Calculate false positive rate (fpr) and true positive rate (tpr)
fpr, tpr, thresholds = roc_curve(y_test, final_preds)

# Calculate Area Under the Curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC Curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='No Skill')  # Reference line for random guessing
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)', fontsize =14)
plt.ylabel('True Positive Rate (TPR)', fontsize= 14)
plt.title('Random Forest Classifier ROC Curve', fontsize= 20)
plt.legend(loc="lower right")
plt.grid(True)
#plt.fill_between(fpr, tpr, color='b', alpha=0.2, label='AUC')  # Adjust 'b' for color and 0.2 for transparency
plt.show()

# %%
importances = rf2.best_estimator_.feature_importances_
rf_importances = pd.Series(importances, index=x_test.columns)
rf_importances = rf_importances.sort_values(ascending=False)[:15]

fig, ax = plt.subplots(figsize=(8,5))
rf_importances.plot.bar(ax=ax)
ax.set_title('Feature importances')
ax.set_ylabel('Mean decrease in impurity')
fig.tight_layout();

# %% [markdown]
# # pacE: Execute Stage
# - Interpret model performance and results
# - Share actionable steps with stakeholders

# %% [markdown]
# ✏
# ## Recall evaluation metrics
#
# - **AUC** is the area under the ROC curve; it's also considered the probability that the model ranks a random positive example more highly than a random negative example.
# - **Precision** measures the proportion of data points predicted as True that are actually True, in other words, the proportion of positive predictions that are true positives.
# - **Recall** measures the proportion of data points that are predicted as True, out of all the data points that are actually True. In other words, it measures the proportion of positives that are correctly classified.
# - **Accuracy** measures the proportion of data points that are correctly classified.
# - **F1-score** is an aggregation of precision and recall.

# %% [markdown]
# 💭
# ### Reflect on these questions as you complete the executing stage.
#
# - What key insights emerged from your model(s)?
# - What business recommendations do you propose based on the models built?
# - What potential recommendations would you make to your manager/company?
# - Do you think your model could be improved? Why or why not? How?
# - Given what you know about the data and the models you were using, what other questions could you address for the team?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# Double-click to enter your responses here.
#
# What key insights emerged from your model(s)?
#
# Key metrics that predict employee retention identified by the feature importance plot are as follows: Satisfaction Level, Tenure, Last Evaluation, Number of Projects, and Average Monthly Hours.
#
# The Random Forest Classifer model is the champion model, which has a 99.0% precision score, 93.4% recall score, 96.2% F1 score, and 98.7% accuracy score.
#
#     The precision score measures the proportion of True Positive (TP) among all predicted positives.
#     A score of 0.99 means that there is a 99% chance that these TP will be calculated correctly. (Predicted)
#
#     The recall score measures the proportion of TPs identified by the model and reflects how well the model finds all the actual positive cases.
#     A score of 0.93 means that there is a 93% chance that a TP will be calculated correctly against all actual positive cases. (Actual)
#
#     An F1 score is a calculation that takes into account both the precision score and recall scores, using the 'harmonic' mean versus the actual mean, since the harmonic mean penalizes models that have low precision or recall scores.
#     An F1 score of 0.96 means that the model performs within a 96% harmonic mean efficacy of both the precision and recall scores.
#
#     The accuracy score measures the proportion of correct predictions made by the model on the testing set. It is calculated as the number of correctly classified data points divided by the total number of data points.
#     An accuracy score of 0.98 means that there is a 98% chance that the model will accurately classify its predictions.
#     Meaning True Positives (TPs) and True Negatives (TNs) will be 98% accurate.
#
# Additional insight discovered during EDA are as follows:
#
# Department + Left + Salary: This is a strong predictive variable.
#
#     Between 68% and 51% of employee attrition per Department based on low Salary are in the following departments in descending order:
#     Marketing, Support, Technical, Management, RandD, Sales, HR, Accounting, IT, Product Management
#
#     Between 44% and 28% of employee attrition per Department based on medium Salary are in the following departments in descending order:
#     IT, Product Management, HR, Sales, Accounting, Management, RandD, Technical, Support, Marketing
#
#     Between 5.5% and 1.3% of employee attrition per Department based on high Salary are in the following departments in descending order:
#     RandD, Product Management, Marketing, Accounting, HR, Technical, Management, IT, Support, Sales
#
# Department + Left + Number of Projects: This is a strong predictive variable.
#
#     Between 69% and 50% of employee attrition per Department were only assigned 2 work projects.
#
#     Conjecture1: Employees left because they felt under-used
#
#     Conjecture2: Employees were poor performers
#
#     Conjecture3: Employees did not want more proojects Between 28% and 16% of employee attrition per Department had exactly 6 projects.
#
#     Conjecture4: Employee left because they were overworked
#
#     Conjecture5: Employee left because the work load was mismanaged Between 16% to 0.8% of employee attrition per Department had 3, 4, 5, or 7 projects.
#
# Department + Left + Promotion: This is a strong predictive variable.
#
#     Between 100% to 97% of employee attrition per Department were not promoted.
#
#     Between 2.3% and 0.36% of employee attrition per Department were promoted.
#     The only 4 offices to promote in the last 5 years were: IT, Sales Support, and Technical
#
# Department + Left + Last Evaluation: Decent predictive variable, but ethically?
#
#     Between 12.8% and 9.2% of employee attrition per Department received poor evaluations between 0.46 to 0.54 (out of 1.00) However, the highest evaluation score of an employee who was not retained is 1.00
#
# Department + Left + Satisfaction Level: Decent predictive variable.
#
#     Between 15% and 18% of employee attrition had extremely low Satisfaction Levels of .10 and .11 respectively.
#     However, the highest Satisfacton level that still churned is 0.90.
#
#
# What business recommendations do you propose based on the models built?
#
#     Based on the model, I believe it will be important to take a closer look at Satisfaction Level, Tenure, Last Evaluation, Number of Projects, and Average Monthly Hours for future testing.
#     Additionally, taking under consideration the other insights pulled from the data during EDA with an emphasis on the 5 feature importance metrics.
#
#
# What potential recommendations would you make to your manager/company?
#
#     There is a large disperity in the average monthly hours per Department.
#     Additionally, the Number of Projects assigned to an employee is a key factor in their overall Satisfaction Level, potentially their Evaluations and whether or not they will leave the company.
#     Additionally, it is important to point out that there have only been promotions in 5 Departments over the past 5 years and  higher percentage of churn per department for employees with lower Salaries.
#     Over 97% of employee attrition per Department were not promoted within the last 5 years.
#     Further study should be conducted on Salaries and employee churn to see what the cost benefit analysis truly is on what the current Salaries are.
#
# Do you think your model could be improved? Why or why not? How?
#
#     The Logistic Regression model has a lot of room for improvement, which is why it was not chosen. This model is highly suceptible to class imbalance, and since the data set has an 83/16 imbalance it suffered. Future testing with this model would require either downsampling of the target variable or upsampling the independent variables.
#
#        The Random Forest Classifier could be improved by adding in new features, potentially time-series features involving average monthly hours per number of projects by department.
#
# Given what you know about the data and the models you were using, what other questions could you address for the team?
#
#     Is there any continuous variable salary data so that we can potentially run a Linear Regression model to find target Salaries per department, should the stakeholders want to pull on that thread.
#
# What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# Do you have any ethical considerations in this stage?
#
#         I have been using previous labs for workflow and inspiration, as well as, Google Gemini.

# %% [markdown]
# ## Step 4. Results and Evaluation
# - Interpret model
# - Evaluate model performance using metrics
# - Prepare results, visualizations, and actionable steps to share with stakeholders

# %% [markdown]
# ### Summary of model results
#
# [Double-click to enter your summary here.]
#
#
# Key metrics that predict employee retention identified by the feature importance plot are as follows: Satisfaction Level, Tenure, Last Evaluation, Number of Projects, and Average Monthly Hours.
#
# The Random Forest Classifer model is the champion model, which has a 99.0% precision score, 93.4% recall score, 96.2% F1 score, and 98.7% accuracy score.
#
#     The precision score measures the proportion of True Positive (TP) among all predicted positives.
#     A score of 0.99 means that there is a 99% chance that these TP will be calculated correctly. (Predicted)
#
#     The recall score measures the proportion of TPs identified by the model and reflects how well the model finds all the actual positive cases.
#     A score of 0.93 means that there is a 93% chance that a TP will be calculated correctly against all actual positive cases. (Actual)
#
#     An F1 score is a calculation that takes into account both the precision score and recall scores, using the 'harmonic' mean versus the actual mean, since the harmonic mean penalizes models that have low precision or recall scores.
#     An F1 score of 0.96 means that the model performs within a 96% harmonic mean efficacy of both the precision and recall scores.
#
#     The accuracy score measures the proportion of correct predictions made by the model on the testing set. It is calculated as the number of correctly classified data points divided by the total number of data points.
#     An accuracy score of 0.98 means that there is a 98% chance that the model will accurately classify its predictions.
#     Meaning True Positives (TPs) and True Negatives (TNs) will be 98% accurate.

# %% [markdown]
# ### Conclusion, Recommendations, Next Steps
#
# [Double-click to enter your conclusion, recommendations, and next steps here.]
#
# What business recommendations do you propose based on the models built?
#
#     Based on the model, I believe it will be important to take a closer look at Satisfaction Level, Tenure, Last Evaluation, Number of Projects, and Average Monthly Hours for future testing.
#     Additionally, taking under consideration the other insights pulled from the data during EDA with an emphasis on the 5 feature importance metrics.
#
#
# What potential recommendations would you make to your manager/company?
#
#     There is a large disperity in the average monthly hours per Department.
#     Additionally, the Number of Projects assigned to an employee is a key factor in their overall Satisfaction Level, potentially their Evaluations and whether or not they will leave the company.
#     Additionally, it is important to point out that there have only been promotions in 5 Departments over the past 5 years and  higher percentage of churn per department for employees with lower Salaries.
#     Over 97% of employee attrition per Department were not promoted within the last 5 years.
#     Further study should be conducted on Salaries and employee churn to see what the cost benefit analysis truly is on what the current Salaries are

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
